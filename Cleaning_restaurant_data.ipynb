# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
from scipy.stats import linregress,pearsonr
import numpy as np

# %%
# Open CSV as Df
raw_data_df = pd.read_csv('Resources/CA-Closing_and_Reopening_Restaurants.csv')
raw_data_df["Action"] = raw_data_df["Action"].replace(np.nan, "none")
raw_data_df.head(20)
# Out:
#    State_Tribe_Territory     County_Name  FIPS_State  FIPS_County  \
# 0                     CA  Alameda County           6            1
# 1                     CA  Alameda County           6            1
# 2                     CA  Alameda County           6            1
# 3                     CA  Alameda County           6            1
# 4                     CA  Alameda County           6            1
# 5                     CA  Alameda County           6            1
# 6                     CA  Alameda County           6            1
# 7                     CA  Alameda County           6            1
# 8                     CA  Alameda County           6            1
# 9                     CA  Alameda County           6            1
# 10                    CA  Alameda County           6            1
# 11                    CA  Alameda County           6            1
# 12                    CA  Alameda County           6            1
# ...

# %%
raw_data_df["Current_order_status"] = raw_data_df["Current_order_status"].replace(np.nan, "none")

# %%
raw_data_df.drop(columns = ["Issuing_Jurisdiction"], inplace = True)

# %%
raw_data_df.drop(columns = ["State_Tribe_Territory"], inplace = True)

# %%
raw_data_df.drop(columns = ["Jurisdiction_Type"], inplace = True)

# %%
raw_data_df["Current_order_status"]=raw_data_df["Current_order_status"].replace(np.nan, "none")

# %%
raw_data_df["Effective_date"]=raw_data_df["Effective_date"].replace(np.nan, "none")

# %%
raw_data_df.drop(columns = ["Expiration_date", "Effective_NA_Reason"], inplace = True)

# %%
raw_data_df.drop(columns = ["Expiration_NA_Reason"], inplace = True)

# %%
raw_data_df.drop(columns = ["origin_dataset"], inplace = True)

# %%
raw_data_df.drop(columns = ["URL"], inplace = True)

# %%
raw_data_df.drop(columns = ["Source_of_Action"], inplace = True)

# %%
raw_data_df["Date_Signed"]=raw_data_df["Date_Signed"].replace(np.nan, "none")

# %%
raw_data_df["Citation"]=raw_data_df["Citation"].replace(np.nan, "none")

# %%
raw_data_df.drop(columns = ["FIPS_State"], inplace = True)

# %%
raw_data_df.head()
# Out:
#       County_Name  FIPS_County            date Business_Type  \
# 0  Alameda County            1  3/15/2020 0:00   Restaurants
# 1  Alameda County            1  3/16/2020 0:00   Restaurants
# 2  Alameda County            1  3/17/2020 0:00   Restaurants
# 3  Alameda County            1  3/18/2020 0:00   Restaurants
# 4  Alameda County            1  3/19/2020 0:00   Restaurants
#
#                             Action             order_group  order_code  \
# 0                             none    No restriction found           1
# 1                             none    No restriction found           1
# 2                             none    No restriction found           1
# 3                             none    No restriction found           1
# 4  Curbside/carryout/delivery only  Curbside/delivery only           4
#
#   Current_order_status Effective_date Date_Signed  \
# 0                 none           none        none
# 1                 none           none        none
# ...

# %%
raw_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16936 entries, 0 to 16935
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   County_Name           16936 non-null  object
#  1   FIPS_County           16936 non-null  int64
#  2   date                  16936 non-null  object
#  3   Business_Type         16936 non-null  object
#  4   Action                16936 non-null  object
#  5   order_group           16936 non-null  object
#  6   order_code            16936 non-null  int64
#  7   Current_order_status  16936 non-null  object
#  8   Effective_date        16936 non-null  object
#  9   Date_Signed           16936 non-null  object
#  10  Citation              16936 non-null  object
# dtypes: int64(2), object(9)
# memory usage: 1.4+ MB

# %% [markdown]
# <h1>Export Clean csv</h1>

# %%
raw_data_df.to_csv('Resources/clean_rest_data.csv', index = False)
